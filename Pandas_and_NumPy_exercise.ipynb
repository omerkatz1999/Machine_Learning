# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from matplotlib import pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
#data = pd.read_csv('mnist.csv')

# %%
x = [1,2,3,4,5]

# %%
a = np.array(x)
print(a)
# Out:
# [1 2 3 4 5]

# %%
x = np.arange(1,10)
print(x)
# Out:
# [1 2 3 4 5 6 7 8 9]

# %%
x = np.arange(0.1,1,1)
print(x)
# Out:
# [0.1]

# %%
dp = np.array([[0,1], [1,0]])
np.shape(dp)
a = np.random.randn(6,4)
print(a)
# Out:
# [[ 0.94071424 -1.86529599 -2.38200978 -0.36070434]
#  [-0.19200111 -0.5613818   0.80470409 -1.51180353]
#  [ 1.10299023 -0.13582252 -0.68273726 -0.40771824]
#  [ 1.22781543 -0.05816379 -0.3901806  -0.412128  ]
#  [ 0.56722472 -2.00296821  1.37810097  0.23949842]
#  [ 1.04714172 -1.300803   -0.53916167 -2.33010184]]

# %%
plt.plot([1,2,3,4],[1,4,9,16], 'ro',[1,2,3,4],[1,8,27,64], 'b^')

#plt.axis([0,20,0,20])
plt.show()

# %%
df = pd.DataFrame(np.random.rand(10,2), columns = ['A','B', 'C', 'D'])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-c42dcb8553bf> in <module>
# ----> 1 df = pd.DataFrame(np.zeros(10,4), columns = ['A','B', 'C', 'D'])
#       2 df
#
# TypeError: data type not understood

# %%
df2 = pd.DataFrame({'A':[10,20], 'B':[12,22], 'C':[7,29] })
df2
# Out:
#     A   B   C
# 0  10  12   7
# 1  20  22  29

# %%
df2.dtypes
df2.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.tail
# Out:
# <bound method NDFrame.tail of           A         B         C         D
# 0  0.502972  0.184355  0.753293  0.670393
# 1  0.153446  0.521400  0.068989  0.648841
# 2  0.412396  0.498124  0.379499  0.419052
# 3  0.964652  0.746034  0.670298  0.928296
# 4  0.750082  0.500656  0.166824  0.148887
# 5  0.037393  0.005310  0.408765  0.837135
# 6  0.688578  0.673304  0.703393  0.801494
# 7  0.808783  0.178232  0.038072  0.096063
# 8  0.861900  0.070949  0.125345  0.726751
# 9  0.043166  0.664308  0.532743  0.750573>

# %%
df.head
# Out:
# <bound method NDFrame.head of           A         B         C         D
# 0  0.502972  0.184355  0.753293  0.670393
# 1  0.153446  0.521400  0.068989  0.648841
# 2  0.412396  0.498124  0.379499  0.419052
# 3  0.964652  0.746034  0.670298  0.928296
# 4  0.750082  0.500656  0.166824  0.148887
# 5  0.037393  0.005310  0.408765  0.837135
# 6  0.688578  0.673304  0.703393  0.801494
# 7  0.808783  0.178232  0.038072  0.096063
# 8  0.861900  0.070949  0.125345  0.726751
# 9  0.043166  0.664308  0.532743  0.750573>

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.522337   0.404267   0.384722   0.602749
# std     0.347342   0.270462   0.274079   0.286901
# min     0.037393   0.005310   0.038072   0.096063
# 25%     0.218183   0.179763   0.135715   0.476499
# 50%     0.595775   0.499390   0.394132   0.698572
# 75%     0.794108   0.628581   0.635909   0.788764
# max     0.964652   0.746034   0.753293   0.928296

# %%
df.sort_index(axis = 0, ascending = True)
# Out:
#           A         B         C         D
# 0  0.502972  0.184355  0.753293  0.670393
# 1  0.153446  0.521400  0.068989  0.648841
# 2  0.412396  0.498124  0.379499  0.419052
# 3  0.964652  0.746034  0.670298  0.928296
# 4  0.750082  0.500656  0.166824  0.148887
# 5  0.037393  0.005310  0.408765  0.837135
# 6  0.688578  0.673304  0.703393  0.801494
# 7  0.808783  0.178232  0.038072  0.096063
# 8  0.861900  0.070949  0.125345  0.726751
# 9  0.043166  0.664308  0.532743  0.750573

# %%
df['A']
# Out:
# 0    0.502972
# 1    0.153446
# 2    0.412396
# 3    0.964652
# 4    0.750082
# 5    0.037393
# 6    0.688578
# 7    0.808783
# 8    0.861900
# 9    0.043166
# Name: A, dtype: float64

# %%
df.sort_values(by = 'B')
# Out:
#           A         B         C         D
# 5  0.037393  0.005310  0.408765  0.837135
# 8  0.861900  0.070949  0.125345  0.726751
# 7  0.808783  0.178232  0.038072  0.096063
# 0  0.502972  0.184355  0.753293  0.670393
# 2  0.412396  0.498124  0.379499  0.419052
# 4  0.750082  0.500656  0.166824  0.148887
# 1  0.153446  0.521400  0.068989  0.648841
# 9  0.043166  0.664308  0.532743  0.750573
# 6  0.688578  0.673304  0.703393  0.801494
# 3  0.964652  0.746034  0.670298  0.928296

# %%
df[0:1]
# Out:
#           A         B         C         D
# 0  0.502972  0.184355  0.753293  0.670393

# %%
df[2:5]
# Out:
#           A         B         C         D
# 2  0.412396  0.498124  0.379499  0.419052
# 3  0.964652  0.746034  0.670298  0.928296
# 4  0.750082  0.500656  0.166824  0.148887

# %%
df[:]
# Out:
#           A         B         C         D
# 0  0.502972  0.184355  0.753293  0.670393
# 1  0.153446  0.521400  0.068989  0.648841
# 2  0.412396  0.498124  0.379499  0.419052
# 3  0.964652  0.746034  0.670298  0.928296
# 4  0.750082  0.500656  0.166824  0.148887
# 5  0.037393  0.005310  0.408765  0.837135
# 6  0.688578  0.673304  0.703393  0.801494
# 7  0.808783  0.178232  0.038072  0.096063
# 8  0.861900  0.070949  0.125345  0.726751
# 9  0.043166  0.664308  0.532743  0.750573

# %%
df.loc[0]
# Out:
# A    0.502972
# B    0.184355
# C    0.753293
# D    0.670393
# Name: 0, dtype: float64

# %%
df.loc[0,'A']
# Out:
# 0.5029723520489103

# %%
df[df.B < 0.5]
# Out:
#           A         B         C         D
# 0  0.502972  0.184355  0.753293  0.670393
# 2  0.412396  0.498124  0.379499  0.419052
# 5  0.037393  0.005310  0.408765  0.837135
# 7  0.808783  0.178232  0.038072  0.096063
# 8  0.861900  0.070949  0.125345  0.726751

# %%
df3 = df[df < 0.6]

# %%
df3
# Out:
#           A         B         C         D
# 0  0.502972  0.184355       NaN       NaN
# 1  0.153446  0.521400  0.068989       NaN
# 2  0.412396  0.498124  0.379499  0.419052
# 3       NaN       NaN       NaN       NaN
# 4       NaN  0.500656  0.166824  0.148887
# 5  0.037393  0.005310  0.408765       NaN
# 6       NaN       NaN       NaN       NaN
# 7       NaN  0.178232  0.038072  0.096063
# 8       NaN  0.070949  0.125345       NaN
# 9  0.043166       NaN  0.532743       NaN

# %%
df3.dropna()
# Out:
#           A         B         C         D
# 2  0.412396  0.498124  0.379499  0.419052

# %%
df3
# Out:
#           A         B         C         D
# 0  0.502972  0.184355       NaN       NaN
# 1  0.153446  0.521400  0.068989       NaN
# 2  0.412396  0.498124  0.379499  0.419052
# 3       NaN       NaN       NaN       NaN
# 4       NaN  0.500656  0.166824  0.148887
# 5  0.037393  0.005310  0.408765       NaN
# 6       NaN       NaN       NaN       NaN
# 7       NaN  0.178232  0.038072  0.096063
# 8       NaN  0.070949  0.125345       NaN
# 9  0.043166       NaN  0.532743       NaN

# %%
df3.fillna(value=0)
# Out:
#           A         B         C         D
# 0  0.502972  0.184355       NaN       NaN
# 1  0.153446  0.521400  0.068989       NaN
# 2  0.412396  0.498124  0.379499  0.419052
# 3       NaN       NaN       NaN       NaN
# 4       NaN  0.500656  0.166824  0.148887
# 5  0.037393  0.005310  0.408765       NaN
# 6       NaN       NaN       NaN       NaN
# 7       NaN  0.178232  0.038072  0.096063
# 8       NaN  0.070949  0.125345       NaN
# 9  0.043166       NaN  0.532743       NaN

# %%
df.mean()
# Out:
# A    0.522337
# B    0.404267
# C    0.384722
# D    0.602749
# dtype: float64

# %%
df.mean(1)
# Out:
# 0    0.527753
# 1    0.348169
# 2    0.427268
# 3    0.827320
# 4    0.391612
# 5    0.322151
# 6    0.716692
# 7    0.280288
# 8    0.446236
# 9    0.497697
# dtype: float64

# %%
births = pd.read_csv('/Users/omerkatz/Downloads/births.csv')
births
# Out:
#       Gender Premie  weight  Apgar1  Fage  Mage  Feduc  Meduc  TotPreg  \
# 0       Male     No     124       8    31    25     13     14        1
# 1     Female     No     177       8    36    26      9     12        2
# 2       Male     No     107       3    30    16     12      8        2
# 3     Female     No     144       6    33    37     12     14        2
# 4       Male     No     117       9    36    33     10     16        2
# ...      ...    ...     ...     ...   ...   ...    ...    ...      ...
# 1987  Female     No     104       8    36    36     12     13        2
# 1988    Male     No     122       9    47    42     17     16        4
# 1989  Female     No     115       8    35    34      9      7        4
# 1990    Male     No     157       8    35    36     16     16        3
# 1991  Female     No     129       9    36    27     12     12        3
#
#       Visits  ... Racemom  Racedad  Hispmom  Hispdad Gained      Habit  \
# ...

# %%
df_empty = pd.DataFrame(columns=['A','B'])
new_row = {'A': 0,'B': 3}
df_empty = df_empty.append(new_row,ignore_index=True)
# Out:
#    A  B
# 0  0  3
